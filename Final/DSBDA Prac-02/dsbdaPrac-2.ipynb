# %%
import pandas as pd
import numpy as np
df=pd.read_csv("./dsbdaPrac-2.csv")

# %%
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year
# 0         75.0           75.0           73.0             73.0            2020  \
# 1         80.0           70.0           70.0             78.0            2021
# 2         72.0           64.0           69.0             76.0            2019
# 3         70.0           60.0           80.0             96.0            2018
# 4          NaN           62.0           70.0             78.0            2022
# 5         73.0           78.0           74.0              NaN            2019
# 6         74.0           64.0           61.0             90.0            2022
# 7         73.0           64.0           64.0             95.0            2019
# 8         63.0           66.0           70.0             67.0            2021
# 9         88.0           78.0           65.0             79.0            2022
# 10        71.0            NaN           69.0             74.0            2022
# ...

# %%
df.isnull()
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year
# 0        False          False          False            False           False  \
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4         True          False          False            False           False
# 5        False          False          False             True           False
# 6        False          False          False            False           False
# 7        False          False          False            False           False
# 8        False          False          False            False           False
# 9        False          False          False            False           False
# 10       False           True          False            False           False
# ...

# %%
series = pd.isnull(df["math score"])
df[series]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python310\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'math score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
series = pd.isnull(df["math_score"])
df[series]
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year
# 4          NaN           62.0           70.0             78.0            2022  \
# 21         NaN           75.0           68.0             99.0            2018
#
#     placement_offer_count
# 4                       2
# 21                      3

# %%
df.notnull()
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year
# 0         True           True           True             True            True  \
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4        False           True           True             True            True
# 5         True           True           True            False            True
# 6         True           True           True             True            True
# 7         True           True           True             True            True
# 8         True           True           True             True            True
# 9         True           True           True             True            True
# 10        True          False           True             True            True
# ...

# %%
series1 = pd.notnull(df["math_score"])
df[series1]
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year
# 0         75.0           75.0           73.0             73.0            2020  \
# 1         80.0           70.0           70.0             78.0            2021
# 2         72.0           64.0           69.0             76.0            2019
# 3         70.0           60.0           80.0             96.0            2018
# 5         73.0           78.0           74.0              NaN            2019
# 6         74.0           64.0           61.0             90.0            2022
# 7         73.0           64.0           64.0             95.0            2019
# 8         63.0           66.0           70.0             67.0            2021
# 9         88.0           78.0           65.0             79.0            2022
# 10        71.0            NaN           69.0             74.0            2022
# 11        67.0           79.0           80.0             70.0            2022
# ...

# %%
missing_values = ["Na", "na"]
df = pd.read_csv("./dsbdaPrac-2.csv", na_values =missing_values)
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year
# 0         75.0           75.0           73.0             73.0            2020  \
# 1         80.0           70.0           70.0             78.0            2021
# 2         72.0           64.0           69.0             76.0            2019
# 3         70.0           60.0           80.0             96.0            2018
# 4          NaN           62.0           70.0             78.0            2022
# 5         73.0           78.0           74.0              NaN            2019
# 6         74.0           64.0           61.0             90.0            2022
# 7         73.0           64.0           64.0             95.0            2019
# 8         63.0           66.0           70.0             67.0            2021
# 9         88.0           78.0           65.0             79.0            2022
# 10        71.0            NaN           69.0             74.0            2022
# ...

# %%
#Filling Null Values

# %%
ndf=df
ndf.fillna(0)
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year
# 0         75.0           75.0           73.0             73.0            2020  \
# 1         80.0           70.0           70.0             78.0            2021
# 2         72.0           64.0           69.0             76.0            2019
# 3         70.0           60.0           80.0             96.0            2018
# 4          0.0           62.0           70.0             78.0            2022
# 5         73.0           78.0           74.0              0.0            2019
# 6         74.0           64.0           61.0             90.0            2022
# 7         73.0           64.0           64.0             95.0            2019
# 8         63.0           66.0           70.0             67.0            2021
# 9         88.0           78.0           65.0             79.0            2022
# 10        71.0            0.0           69.0             74.0            2022
# ...

# %%
df['math_score'] = df['math_score'].fillna(df['math_score'].mean())
df['math_score'] = df['math_score'].fillna(df['math_score'].median())
df['math score'] = df['math score'].fillna(df['math score'].std())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python310\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'math score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['math_score'] = df['math_score'].fillna(df['math_score'].mean())
df['math_score'] = df['math_score'].fillna(df['math_score'].median())
df['math_score'] = df['math_score'].fillna(df['math_score'].std())

# %%
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year
# 0    75.000000           75.0           73.0             73.0            2020  \
# 1    80.000000           70.0           70.0             78.0            2021
# 2    72.000000           64.0           69.0             76.0            2019
# 3    70.000000           60.0           80.0             96.0            2018
# 4    69.518519           62.0           70.0             78.0            2022
# 5    73.000000           78.0           74.0              NaN            2019
# 6    74.000000           64.0           61.0             90.0            2022
# 7    73.000000           64.0           64.0             95.0            2019
# 8    63.000000           66.0           70.0             67.0            2021
# 9    88.000000           78.0           65.0             79.0            2022
# 10   71.000000            NaN           69.0             74.0            2022
# ...

# %%
m_v=df['math_score'].mean()
df['math_score'].fillna(value=m_v, inplace=True)
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year
# 
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year
# 0    75.000000           75.0           73.0             73.0            2020  \
# 1    80.000000           70.0           70.0             78.0            2021
# 2    72.000000           64.0           69.0             76.0            2019
# 3    70.000000           60.0           80.0             96.0            2018
# 4    69.518519           62.0           70.0             78.0            2022
# 6    74.000000           64.0           61.0             90.0            2022
# 7    73.000000           64.0           64.0             95.0            2019
# 8    63.000000           66.0           70.0             67.0            2021
# 9    88.000000           78.0           65.0             79.0            2022
# 11   67.000000           79.0           80.0             70.0            2022
# 12   61.000000           77.0           92.0             92.0            2018
# ...

# %%
col = ['math_score', 'reading_score' , 'writing_score','placement_score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(df['math score']>90))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python310\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'math score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
print(np.where(df['math_score']>90))
# Out:
# (array([], dtype=int64),)

# %%
print(np.where(df['reading_score']<25))
print(np.where(df['writing_score']<30))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['placement_score'], df['placement_offer_count'])
plt.show()

# %%
ax.set_xlabel('(Proportion non-retail businessacres)/(town)')
ax.set_ylabel('(Full-value property-tax rate)/($10,000)')
# Out:
# Text(4.444444444444452, 0.5, '(Full-value property-tax rate)/($10,000)')

# %%
print(np.where((df['placemen_score']<50) & (df['placement_offer_count']>1)))
print(np.where((df['placement_core']>85) & (df['placement_offer_count']<3)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python310\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'placemen_score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
print(np.where((df['placement_score']<50) & (df['placement_offer_count']>1)))
print(np.where((df['placement_score']>85) & (df['placement_print(z)offer_count']<3)))
# Out:
# (array([], dtype=int64),)
# (array([ 7, 26], dtype=int64),)

# %%
from scipy import stats
z = np.abs(stats.zscore(df['math_score']))
print(z)
# Out:
# 0     0.822269
# 1     1.572313
# 2     0.372244
# 3     0.072226
# 4     0.000000
# 5     0.522252
# 6     0.672261
# 7     0.522252
# 8     0.977834
# 9     2.772382
# 10    0.222235
# 11    0.377799
# 12    1.277851
# 13    0.372244
# 14    1.127843
# 15    0.077782
# 16    0.527808
# 17    0.827825
# 18    0.977834
# 19    1.572313
# 20    0.677817
# 21    0.000000
# 22    0.222235
# 23    0.977834
# 24    1.427860
# 25    1.122287
# 26    0.822269
# 27    1.427860
# 28    0.977834
# Name: math_score, dtype: float64

# %%
threshold = 0.65

# %%
sample_outliers = np.where(z <threshold)
sample_outliers
# Out:
# (array([ 2,  3,  4,  5,  7, 10, 11, 13, 15, 16, 21, 22], dtype=int64),)

# %%
sorted_rscore= sorted(df['reading_score'])
sorted_rscore
q1 = np.percentile(sorted_rscore, 25)
q3 = np.percentile(sorted_rscore, 75)
print(q1,q3)
# Out:
# nan nan

# %%
IQR = q3-q1
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)

# %%
print(lwr_bound, upr_bound)
# Out:
# nan nan

# %%
r_outliers = []
for i in sorted_rscore:
    if (i<lwr_bound or i>upr_bound):
        r_outliers.append(i)
print(r_outliers)
# Out:
# []

# %%
new_df=df
for i in sample_outliers:
    new_df.drop(i,inplace=True)
new_df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year
# 0         75.0           75.0           73.0             73.0            2020  \
# 1         80.0           70.0           70.0             78.0            2021
# 6         74.0           64.0           61.0             90.0            2022
# 8         63.0           66.0           70.0             67.0            2021
# 9         88.0           78.0           65.0             79.0            2022
# 12        61.0           77.0           92.0             92.0            2018
# 14        62.0           72.0           62.0             95.0            2022
# 17        64.0           76.0           70.0             99.0            2022
# 18        63.0           78.0            NaN             62.0            2021
# 19        80.0           67.0           78.0             68.0            2020
# 20        65.0           63.0           61.0             98.0            2020
# ...

# %%
df=pd.read_csv("./dsbdaPrac-2.csv")
df_stud=df
ninetieth_percentile = np.percentile(df_stud['math_score'], 90)
b = np.where(df_stud['math_score']>ninetieth_percentile,
ninetieth_percentile, df_stud['math_score'])
print("New array:",b)
# Out:
# New array: [75. 80. 72. 70. nan 73. 74. 73. 63. 88. 71. 67. 61. 72. 62. 69. 66. 64.
#  63. 80. 65. nan 71. 63. 60. 77. 75. 60. 63.]

# %%
df_stud.insert(1,"m score",b,True)
df_stud
# Out:
#     math_score  m score  reading_score  writing_score  placement_score
# 0         75.0     75.0           75.0           73.0             73.0  \
# 1         80.0     80.0           70.0           70.0             78.0
# 2         72.0     72.0           64.0           69.0             76.0
# 3         70.0     70.0           60.0           80.0             96.0
# 4          NaN      NaN           62.0           70.0             78.0
# 5         73.0     73.0           78.0           74.0              NaN
# 6         74.0     74.0           64.0           61.0             90.0
# 7         73.0     73.0           64.0           64.0             95.0
# 8         63.0     63.0           66.0           70.0             67.0
# 9         88.0     88.0           78.0           65.0             79.0
# 10        71.0     71.0            NaN           69.0             74.0
# 11        67.0     67.0           79.0           80.0             70.0
# ...

# %%
col = ['reading_score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
median=np.median(sorted_rscore)
median
# Out:
# nan

# %%
refined_df=df
refined_df['reading_score'] = np.where(refined_df['reading_score'] >upr_bound, median,refined_df['reading_score'])

# %%
refined_df['reading_score'] = np.where(refined_df['reading_score'] <lwr_bound, median,refined_df['reading_score'])
col = ['reading_score']
refined_df.boxplot(col)
# Out:
# <Axes: >

# %%
plt.show()

# %%
refined_df
# Out:
#     math_score  m score  reading_score  writing_score  placement_score
# 0         75.0     75.0           75.0           73.0             73.0  \
# 1         80.0     80.0           70.0           70.0             78.0
# 2         72.0     72.0           64.0           69.0             76.0
# 3         70.0     70.0           60.0           80.0             96.0
# 4          NaN      NaN           62.0           70.0             78.0
# 5         73.0     73.0           78.0           74.0              NaN
# 6         74.0     74.0           64.0           61.0             90.0
# 7         73.0     73.0           64.0           64.0             95.0
# 8         63.0     63.0           66.0           70.0             67.0
# 9         88.0     88.0           78.0           65.0             79.0
# 10        71.0     71.0            NaN           69.0             74.0
# 11        67.0     67.0           79.0           80.0             70.0
# ...

# %%
import matplotlib.pyplot as plt
new_df['math_score'].plot(kind = 'hist')
df['log_math'] = np.log10(df['math_scre'])
df['log_math'].plot(kind = 'hist')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python310\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'math_scre'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import matplotlib.pyplot as plt
new_df['math_score'].plot(kind = 'hist')
df['log_math'] = np.log10(df['math_score'])
df['log_math'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.show()
