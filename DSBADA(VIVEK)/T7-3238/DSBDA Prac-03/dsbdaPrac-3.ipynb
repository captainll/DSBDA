# %%
import pandas as pd
df = pd.read_csv("./income.csv")
df.head()
# Out:
#   age_group  income
# 0     18-30     440
# 1     51-70     567
# 2     18-30     430
# 3     18-30      38
# 4     18-30     204

# %%
df.age_group.unique()
# Out:
# array(['18-30', '51-70', '31-50'], dtype=object)

# %%
df.groupby(df.age_group).count()
# Out:
#            income
# age_group
# 18-30           8
# 31-50           9
# 51-70          12

# %%
df.groupby(df.age_group).min()
# Out:
#            income
# age_group
# 18-30           6
# 31-50           9
# 51-70         231

# %%
df.groupby(df.age_group).max()
# Out:
#            income
# age_group
# 18-30         738
# 31-50         710
# 51-70         702

# %%
df.groupby(df.age_group).mean()
# Out:
#                income
# age_group
# 18-30      362.375000
# 31-50      472.222222
# 51-70      461.833333

# %%
df.groupby(df.age_group).std()
# Out:
#                income
# age_group
# 18-30      269.889892
# 31-50      243.456247
# 51-70      171.291794

# %%
df.groupby(df.age_group).std()
# Out:
#                income
# age_group
# 18-30      269.889892
# 31-50      243.456247
# 51-70      171.291794

# %%
df.groupby(df.age_group).describe()
# Out:
#           income
#            count        mean         std    min     25%    50%    75%    max
# age_group
# 18-30        8.0  362.375000  269.889892    6.0  162.50  396.5  500.0  738.0
# 31-50        9.0  472.222222  243.456247    9.0  359.00  570.0  649.0  710.0
# 51-70       12.0  461.833333  171.291794  231.0  326.75  448.5  620.5  702.0

# %%
from sklearn import datasets 
data = datasets.load_iris() 
df1 = pd.DataFrame(data.data,columns=data.feature_names) 
df1['species'] = pd.Series(data.target) 
df1.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
df1.species.unique()
# Out:
# array([0, 1, 2])

# %%
df1.groupby(df1.species)

# %%
df1.groupby(df1.species).count()
# Out:
#          sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# 0                       50                50                 50
# 1                       50                50                 50
# 2                       50                50                 50
#
#          petal width (cm)
# species
# 0                      50
# 1                      50
# 2                      50

# %%
df1.groupby(df1.species).max()
# Out:
#          sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# 0                      5.8               4.4                1.9
# 1                      7.0               3.4                5.1
# 2                      7.9               3.8                6.9
#
#          petal width (cm)
# species
# 0                     0.6
# 1                     1.8
# 2                     2.5

# %%
df1.groupby(df1.species).min()
# Out:
#          sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# 0                      4.3               2.3                1.0
# 1                      4.9               2.0                3.0
# 2                      4.9               2.2                4.5
#
#          petal width (cm)
# species
# 0                     0.1
# 1                     1.0
# 2                     1.4

# %%
df1.groupby(df1.species).mean()
# Out:
#          sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# 0                    5.006             3.428              1.462
# 1                    5.936             2.770              4.260
# 2                    6.588             2.974              5.552
#
#          petal width (cm)
# species
# 0                   0.246
# 1                   1.326
# 2                   2.026

# %%
df1.groupby(dspecies).std()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2016\952280641.py in <module>
# ----> 1 df1.groupby(dspecies).std()
#
# NameError: name 'dspecies' is not defined

# %%
df.groupby(df.species).std()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2016\3500615208.py in <module>
# ----> 1 df.groupby(df.species).std()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'species'

# %%
df1.groupby(df1.species).std()
# Out:
#          sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# 0                 0.352490          0.379064           0.173664
# 1                 0.516171          0.313798           0.469911
# 2                 0.635880          0.322497           0.551895
#
#          petal width (cm)
# species
# 0                0.105386
# 1                0.197753
# 2                0.274650

# %%
df1.groupby(df1.species)["sepal length (cm)"].describe()
# Out:
#          count   mean       std  min    25%  50%  75%  max
# species
# 0         50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# 1         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# 2         50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9

# %%
df1.groupby(df1.species)["sepal width(cm)"].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2016\1189834781.py in <module>
# ----> 1 df1.groupby(df1.species)["sepal width(cm)"].describe()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1336                 stacklevel=find_stack_level(),
#    1337             )
# -> 1338         return super().__getitem__(key)
#    1339
#    1340     def _gotitem(self, key, ndim: int, subset=None):
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     248         else:
#     249             if key not in self.obj:
# --> 250                 raise KeyError(f"Column not found: {key}")
#     251             subset = self.obj[key]
#     252             ndim = subset.ndim
#
# KeyError: 'Column not found: sepal width(cm)'

# %%
df1.groupby(df1.species)["sepal width (cm)"].describe()
# Out:
#          count   mean       std  min    25%  50%    75%  max
# species
# 0         50.0  3.428  0.379064  2.3  3.200  3.4  3.675  4.4
# 1         50.0  2.770  0.313798  2.0  2.525  2.8  3.000  3.4
# 2         50.0  2.974  0.322497  2.2  2.800  3.0  3.175  3.8

# %%
df1.groupby(df1.species)["petal length (cm)"].describe()
# Out:
#          count   mean       std  min  25%   50%    75%  max
# species
# 0         50.0  1.462  0.173664  1.0  1.4  1.50  1.575  1.9
# 1         50.0  4.260  0.469911  3.0  4.0  4.35  4.600  5.1
# 2         50.0  5.552  0.551895  4.5  5.1  5.55  5.875  6.9

# %%
df1.groupby(df1.species)["petal width (cm)"].describe()
# Out:
#          count   mean       std  min  25%  50%  75%  max
# species
# 0         50.0  0.246  0.105386  0.1  0.2  0.2  0.3  0.6
# 1         50.0  1.326  0.197753  1.0  1.2  1.3  1.5  1.8
# 2         50.0  2.026  0.274650  1.4  1.8  2.0  2.3  2.5
